# %%
#spacy specify each entity as one of the following :

# PERSON:      People, including fictional.
# NORP:        Nationalities or religious or political groups.
# FAC:         Buildings, airports, highways, bridges, etc.
# ORG:         Companies, agencies, institutions, etc.
# GPE:         Countries, cities, states.
# LOC:         Non-GPE locations, mountain ranges, bodies of water.
# PRODUCT:     Objects, vehicles, foods, etc. (Not services.)
# EVENT:       Named hurricanes, battles, wars, sports events, etc.
# WORK_OF_ART: Titles of books, songs, etc.
# LAW:         Named documents made into laws.
# LANGUAGE:    Any named language.
# DATE:        Absolute or relative dates or periods.
# TIME:        Times smaller than a day.
# PERCENT:     Percentage, including ”%“.
# MONEY:       Monetary values, including unit.
# QUANTITY:    Measurements, as of weight or distance.
# ORDINAL:     “first”, “second”, etc.
# CARDINAL:    Numerals that do not fall under another type.

# %%
pip install spacy
pip install nltk

#run in console
#python -m spacy download en_core_web_sm
# Out:
#   Cell In[2], line 1
#     pip install spacy
#         ^
# SyntaxError: invalid syntax

# %%
import spacy 
from langchain_community.document_loaders import PyPDFLoader

#en_core_web_sm is a pre-trained small English language model for spaCy, trained on a massive amount of English text data
ner = spacy.load("en_core_web_sm")

# %%
#pdf 1 - Harry Potter and the Death Hallows Summary.pdf
from spacy import displacy

loader = PyPDFLoader('../data/Harry Potter and the Death Hallows Summary.pdf')
pages = loader.load_and_split()

contents=''
for i in range(0,len(pages)):
    contents=' '.join([contents,pages[i].page_content.replace('\n',' ')])

doc = ner(contents) 
displacy.render(doc, style="ent") 
for entity in doc.ents:
  print(entity.label_, ' | ', entity.text)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Maranatha Christian University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  SUMMARY
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harry Potter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and the Deathly Hallows       Harry,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and Hermione go to find and destroy the last of Lord Voldemort’s  Horcruxes in which he keeps his soul in order to kill him. However it is a difficult task.  They do not even know where they must f ind it because the horcruxes have already  disappeared for a long time and they have no experience at all. Because of their lack of  plan, lack of food, and lack of progress,  their spirits are often low, and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  especially  becomes argumentative.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     One night
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  he  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  get  into a  fight and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  leaves to go  back home.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and Hermione  go to find and destroy the last of Lord Voldemort’s  Horcruxes in which he keeps his soul in order to kill him.  However it is a difficult task.  They do not even know where they must find it because the horcruxes have already  disappeared for a long time and they have no experience at all. Because of their lack of  plan, lack of food, and lack of progress, their spirits are often low, and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  especially  becomes argumentative. O ne night he and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  get  into a  fight and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  leaves to go  back home .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and Hermione decide to visit
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Godric’s Hollow
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in  order to search clues, and  once again they a re almost caught by  Lord  Voldemort.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  back
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a few weeks later
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and  saves
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Harry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s life in the nick of time. They manage to destroy another
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Horcrux
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  with
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gryffindor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s sword, and they become excited again as they begin to learn about a  mysterious trio of magical objects called
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Deathly Hallows
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# . The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1;
# ORG  |  Maranatha Christian University
# CARDINAL  |  19
# PERSON  |  Harry Potter
# PERSON  |  Ron
# PERSON  |  Ron
# TIME  |  One night
# PERSON  |  Harry
# PERSON  |  Ron
# PERSON  |  Harry
# PERSON  |  Ron
# PERSON  |  Ron
# PERSON  |  Harry
# PERSON  |  Ron
# PERSON  |  Harry
# ORG  |  Godric’s Hollow
# PERSON  |  Ron
# DATE  |  a few weeks later
# PERSON  |  Harry
# PERSON  |  Horcrux
# PERSON  |  Gryffindor
# PRODUCT  |  the Deathly Hallows
# CARDINAL  |  three
# ORG  |  Maranatha Christian University
# CARDINAL  |  20
# CARDINAL  |  three
# PERSON  |  Harry
# PERSON  |  Dumbledore
# PERSON  |  Harry
# LOC  |  Snape
# PERSON  |  Harry
# PERSON  |  Harry
# ORDINAL  |  seventh
# PERSON  |  Harry
# PERSON  |  Dumbledore
# PERSON  |  Dumbledore
# PERSON  |  Harry
# PERSON  |  Voldemort
# PERSON  |  Harry
# PERSON  |  Harry
# PERSON  |  Harry
# PERSON  |  J  K Rowling
# DATE  |  July 31 , 1965
# GPE  |  Chipping Sodbury
# PERSON  |  Gloucestershire
# GPE  |  England
# PERSON  |  Joanne Kat
# CARDINAL  |  5 or
# DATE  |  6 years old
# ORDINAL  |  first
# PERSON  |  Miss Bee
# PERSON  |  Rowling
# ORG  |  Maranatha Christian University
# DATE  |  nine years old
# ORG  |  Tutshill
# ORG  |  Wyedean Comprehensive
# ORG  |  Exeter University
# NORP  |  French
# DATE  |  26 years old
# GPE  |  Portugal
# LANGUAGE  |  English
# GPE  |  Portugal
# NORP  |  Portuguese
# PERSON  |  Jessica
# DATE  |  1993
# GPE  |  Edinburgh
# PERSON  |  Harry Potter
# PERSON  |  Harry Potter
# WORK_OF_ART  |  The Philosopher's Stone
# PERSON  |  Bloomsbury
# GPE  |  UK
# DATE  |  several months
# PERSON  |  Arthur A Le
# ORG  |  Books/Scholastic Press
# NORP  |  American
# ORDINAL  |  first
# WORK_OF_ART  |  Harry Potter

# %%
#pdf 2 - About Amazon.pdf

from spacy import displacy

loader = PyPDFLoader('../data/About Amazon.pdf')
pages = loader.load_and_split()

contents=''
for i in range(0,len(pages)):
    contents=' '.join([contents,pages[i].page_content.replace('\n',' ')])

doc = ner(contents) 
displacy.render(doc, style="ent")

# %%
#pdf 3 - Apple stock during pandemic.pdf

from spacy import displacy

loader = PyPDFLoader('../data/Apple stock during pandemic.pdf')
pages = loader.load_and_split()

contents=''
for i in range(0,len(pages)):
    contents=' '.join([contents,pages[i].page_content.replace('\n',' ')])

doc = ner(contents) 
displacy.render(doc, style="ent")

# %%
#pdf 4 - Bank of America Q23.pdf

from spacy import displacy

loader = PyPDFLoader('../data/Bank of America Q23.pdf')
pages = loader.load_and_split()

contents=''
for i in range(0,len(pages)):
    contents=' '.join([contents,pages[i].page_content.replace('\n',' ')])

doc = ner(contents) 
displacy.render(doc, style="ent")
